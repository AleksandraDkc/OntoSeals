# %%
import xml.etree.ElementTree as ET
import datetime
from rdflib.graph import Graph, Literal, Namespace, URIRef
from rdflib.namespace import Namespace, OWL, RDF, RDFS, FOAF, DCTERMS, XSD, SDO

DBpedia = Namespace("http://dbpedia.org/resource/")
SCHEMA = Namespace("http://schema.org/")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
DC = Namespace("http://purl.org/dc/elements/1.1/")

OntoSeals = Namespace("http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#")

g = Graph()
g.bind("OntoSeals", OntoSeals)
g.bind("DBpedia", DBpedia)
g.bind("schema", SCHEMA)
g.bind("foaf", FOAF)
g.bind("dc", DC)

#Fonctions creation classes et objectProperty
def createClass(name):
    concept = URIRef(OntoSeals[name])
    g.add((concept, RDF.type, OWL.Class))
    return concept


def createObjectRelation(name, domainType, rangeType):
    rel = URIRef(OntoSeals[name])
    g.add((rel, RDF.type, OWL.ObjectProperty))
    if domainType is not None:
        dom = OntoSeals[domainType]
        g.add((rel, RDFS.domain, dom))
    if rangeType is not None:
        ran = OntoSeals[rangeType]
        g.add((rel, RDFS.range, ran))
    return rel

#Creation classes
titre = createClass("Titre")
personne = createClass("Personne")
materiau = createClass("Materiel")
inventaire = createClass("Sceau")
collection = createClass("Collection")
periode = createClass("Periode")

# création de relations entre les domaines créées:
est_de_type = createObjectRelation("est_de_type","Sceau","Titre")
appartient_a = createObjectRelation("appartient_a","Sceau","Personne")
a_materiau = createObjectRelation("a_materiel","Sceau","Materiel")
est_ds_collection = createObjectRelation("a_collection","Sceau","Collection")
a_periode = createObjectRelation("a_periode","Sceau","Periode")

# %%
from itertools import count
class Sceau :
    #constructeur
    _ids = count(1)
    def __init__(self, titre, person, date,datestr, dateend,materiaux,inventaire,collection,periode, mention_obligatoire,avers, revers, desc,biblio): 
        #,  dateend
        #materiaux,collection,periode,mention_obligatoire, person, date, inventaire, avers,revers, desc,biblio,fonction1, fonction2, fonction3, fonction4, fonction5
        self.id = next(self._ids)
        self.titre = titre        
        self.person = person
        self.date = date
        self.datestr = datestr
        self.dateend = dateend
        #self.diametre = diametre
        self.inventaire = inventaire
        self.collection = collection        
        self.avers = avers
        self.revers = revers
        self.desc = desc
        self.biblio = biblio
        self.materiaux = materiaux
        self.periode = periode
        self.mention_obligatoire = mention_obligatoire
    
        #fonction pour créer les triplets
    def addInstance(self):        
        inven = URIRef(inst[self.inventaire])
        pers = URIRef(OntoSeals[self.person])
        mat = URIRef(inst[self.materiaux])
        collection = URIRef(inst[self.collection])
        perio = URIRef(inst[self.periode])
        #ment = URIRef(inst[self.mention_obligatoire])
        tit = URIRef(inst[self.titre])
        #perio = URIRef(inst[self.periode])
        #créer les litéraux
        avers = Literal(self.avers, datatype=XSD['string'])
        dat = Literal(self.date, datatype=XSD['string'])
        datestart = Literal(self.datestr, datatype=XSD['int'])
        dateEnd = Literal(self.dateend, datatype=XSD['int'])
        #diam = Literal(self.diametre)
        #person = Literal(self.person)
        materiaux = Literal(self.materiaux)
        #collection = Literal(self.collection)
        periode = Literal(self.periode)
        mentionObligatoire = Literal(self.mention_obligatoire)
        revers = Literal(self.revers, datatype=XSD['string'])
        description = Literal(self.desc, datatype=XSD['string'])
        bibliographie = Literal(self.biblio, datatype=XSD['string'])
        #titre = Literal(self.titre)
        
        #ajouter les triplets au graphe
        g.add((inven, RDF.type, OWL.NamedIndividual))
        g.add((inven, RDF.type,OntoSeals['Sceau']))
        g.add((pers, RDF.type, OWL.NamedIndividual))
        g.add((pers, RDF.type,OntoSeals['Personne']))               
        #graph.add((pers, RDF.type,OntoSeals['Personne']))
        #g.add((inven,OntoSeals['a_collection'],coll))
        g.add((inven,OntoSeals['appartient_a'],pers))
        g.add((inst['date'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['date'],dat))
        g.add((inst['date_start'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['date_start'],datestart))
        g.add((inst['date_end'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['date_end'],dateEnd))
        g.add((inst['avers'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['avers'],avers))
        g.add((inven,OntoSeals['a_periode'],perio)) 
        g.add((inst['revers'], RDF.type, OWL.DatatypeProperty))       
        g.add((inven,inst['revers'],revers))
        g.add((inst['description'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['description'],description))
        g.add((inst['bibliographie'], RDF.type, OWL.DatatypeProperty))
        g.add((inven,inst['bibliographie'],bibliographie))
        g.add((inven,OntoSeals['est_de_type'],tit))
        g.add((inven,OntoSeals['a_materiel'],mat))
        #g.add((inven,OntoSeals['collection'],collection))
        g.add((inst['mentionObligatoire'], RDF.type, OWL.DatatypeProperty))        
        g.add((inven,inst['mentionObligatoire'],mentionObligatoire))
        g.add((pers,RDF.type,OWL.NamedIndividual))
        g.add((pers,RDF.type,OntoSeals['Personne']))
        g.add((mat,RDF.type,OWL.NamedIndividual))
        g.add((mat, RDF.type,OntoSeals['Materiel']))
        g.add((collection,RDF.type,OWL.NamedIndividual))
        g.add((collection, RDF.type,OntoSeals['Collection']))
        #graph.add((perio,RDF.type,OWL.NamedIndividual))
        #graph.add((perio, RDF.type, OntoSeals['Periode']))
        g.add((tit,RDF.type,OWL.NamedIndividual))
        g.add((tit, RDF.type,OntoSeals['Titre']))
        #g.add((ment,RDF.type,OWL.NamedIndividual))
        #g.add((ment, RDF.type,OntoSeals['MentionObligatoire']))

# %%
# Charger le fichier XML
tree = ET.parse('Sceaux_byzantins_v20_Asmae.xml')
root = tree.getroot()

### Extraction du contenu des balises :

#création de listes pour stocker le contenu textuel extrait entre les balises
materiaux_lst = []
personnes_lst = []
dates_lst = []
inventaires_lst = []

titres_lst = []
collections_lst = []
periodes_lst = []
mention_obligatoires_lst = []
avers_lst = []
revers_lst = []
descriptions_lst = []
bibliographies_lst= []
# articles_lst = []

#boucle for pour extraire le contenu des balises:
for objet in root.findall('Seal'):
    objet_materiau = objet.find('Materiaux')
    if objet_materiau is not None:
        objet_materiau = objet.find('Materiaux').text
        objet_materiau = "_".join(objet_materiau.split())
    objet_personnes = objet.find('Person')
    if objet_personnes is not None:
        objet_personnes = objet.find('Person').text
        objet_personnes = "_".join(objet_personnes.split())
    try:
        objet_date = objet.find('Date').text
    except AttributeError:
        pass
    try:
        objet_datesStart = objet.find('DateStart').text
    except AttributeError:
        pass
        
    try:
        objet_datesEnd = objet.find('DateEnd').text
    except AttributeError:
        pass
    objet_inventaire = objet.find('Inventaire')
    if objet_inventaire is not None and objet_inventaire.text is not None:
        objet_inventaire = "_".join(objet_inventaire.text.split())
    else:
        objet_inventaire = ""
    
    objet_titre = objet.find('Titre')
    if objet_titre is not None and objet_titre.text is not None:
        objet_titre = "_".join(objet_titre.text.split())
    else:
        pass
        
    objet_collection = objet.find('Collection')
    if objet_collection is not None and objet_collection.text is not None:
        objet_collection = "_".join(objet_collection.text.split())
    else:
        pass
        
    try:
        objet_periode = objet.find('Periode').text
        objet_periode = "_".join(objet_periode.split())
    except AttributeError:
        pass
    
    objet_mention_obligatoire = objet.find('Mention_obligatoire')
    if objet_mention_obligatoire is not None:
        objet_mention_obligatoire = objet.find('Mention_obligatoire').text
  
    avers_element = root.find('.//Avers')

    # Vérifier si la balise <Avers> existe
    if avers_element is not None:
        # Extraire tout le texte indépendamment des balises internes
        objet_avers = ''.join(avers_element.itertext())
        
    revers_element = root.find('.//Revers')
    if revers_element is not None:
        # Extraire tout le texte indépendamment des balises internes
        objet_revers = ''.join(revers_element.itertext())
        
    description_element = root.find('.//Description')
    if description_element is not None:
        # Extraire tout le texte indépendamment des balises internes
        objet_description = ''.join(description_element.itertext())        
        
    bibliographie_element = root.find('.//Bibliographie')
    if bibliographie_element is not None:
        # Extraire tout le texte indépendamment des balises internes
        objet_bibliographie = ''.join(bibliographie_element.itertext())
        article_element = root.find('.//Article')
        if article_element is not None:
            # Extraire tout le texte indépendamment des balises internes
            objet_bibliographie = ''.join(article_element.itertext()) 
        
    #objet_article = objet.find('Article').text
    
    
    #objet_dates = objet_dates.split(";")
    #objet_personnes = objet_personnes.split(";")

    liste_instance = []
    liste_ent = []
    liste_obj = []
    
    instances = Sceau(objet_titre,objet_personnes,objet_date, objet_datesStart, objet_datesEnd, objet_materiau,objet_inventaire,objet_collection,
                  objet_periode,objet_mention_obligatoire,objet_avers,objet_revers,
                  objet_description,objet_bibliographie)
    #, , 
    liste_instance.append(instances)
    liste_ent.append (instances)
    liste_obj.append(instances)
    for l in liste_instance :
        liste = l.addInstance()

# %%
print(g.serialize(format="turtle"))
#graph.serialize('OntoSeals2.ttl', format="turtle")
g.serialize('OntoSeals11test.ttl', format="turtle")
# Out:
# @prefix OntoSeals: <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# OntoSeals:Byzantine_et_copte_Numismatique a OntoSeals:Collection,
#         owl:NamedIndividual .
#
# OntoSeals:CdN_2004-0215 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Zôsimas_Rhizaios ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "fin 13e s.- début 14e s."^^xsd:string ;
#     OntoSeals:date_end "1400"^^xsd:int ;
#     OntoSeals:date_start "1250"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0248 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Jean ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1080 – 1100"^^xsd:string ;
#     OntoSeals:date_end "1100"^^xsd:int ;
#     OntoSeals:date_start "1080"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0269 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Athanase_Ier ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1289 – 1309"^^xsd:string ;
#     OntoSeals:date_end "1309"^^xsd:int ;
#     OntoSeals:date_start "1289"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_PATRIARCAL ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0274 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Alexis_Stouditès ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1025 – 1043"^^xsd:string ;
#     OntoSeals:date_end "1043"^^xsd:int ;
#     OntoSeals:date_start "1025"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_PATRIARCAL ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0289 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Théodora ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1055 – 1056"^^xsd:string ;
#     OntoSeals:date_end "1056"^^xsd:int ;
#     OntoSeals:date_start "1055"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:BULLE_IMPÉRIALE ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0313 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Alliage_cuivreux ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Sophia ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "seconde moitié du 10e s."^^xsd:string ;
#     OntoSeals:date_end "1000"^^xsd:int ;
#     OntoSeals:date_start "950"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:TESSÈRE_DE_CHARITÉ ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0319 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Joseph ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "fin du 12e s."^^xsd:string ;
#     OntoSeals:date_end "1200"^^xsd:int ;
#     OntoSeals:date_start "1150"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0322 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Michel_Atouémès ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "seconde moitié du 13e s."^^xsd:string ;
#     OntoSeals:date_end "1300"^^xsd:int ;
#     OntoSeals:date_start "1250"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0355 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Maria_Makrembolitissa ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1070 – 1080"^^xsd:string ;
#     OntoSeals:date_end "1080"^^xsd:int ;
#     OntoSeals:date_start "1070"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0362 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Léontios ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "2e moitié 9e s."^^xsd:string ;
#     OntoSeals:date_end "900"^^xsd:int ;
#     OntoSeals:date_start "850"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0372 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Michel_Stryphnos ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "avant 1192"^^xsd:string ;
#     OntoSeals:date_end "1192"^^xsd:int ;
#     OntoSeals:date_start "None"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0373 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Tibère_Empire_byzantin_Justinien_II ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "705 – 711"^^xsd:string ;
#     OntoSeals:date_end "711"^^xsd:int ;
#     OntoSeals:date_start "705"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:BULLE_IMPÉRIALE ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0374 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Fer ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Nicéphore_de_Méloé ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "11e s."^^xsd:string ;
#     OntoSeals:date_end "1100"^^xsd:int ;
#     OntoSeals:date_start "1000"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:BOULLÔTÈRION ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0379 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Grégoire ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "2e moitié 11e s."^^xsd:string ;
#     OntoSeals:date_end "1100"^^xsd:int ;
#     OntoSeals:date_start "1050"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0407 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Michel_VIII_Palaiologue ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1261 – 1282"^^xsd:string ;
#     OntoSeals:date_end "1282"^^xsd:int ;
#     OntoSeals:date_start "1261"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:BULLE_IMPÉRIALE ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0426 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Anonyme ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "12e s."^^xsd:string ;
#     OntoSeals:date_end "1200"^^xsd:int ;
#     OntoSeals:date_start "1150"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0433a a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Trésor_de_la_Grande_Eglise ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "milieu 11e s. (?)- 1ère moitié 12e s. (?)"^^xsd:string ;
#     OntoSeals:date_end "1150"^^xsd:int ;
#     OntoSeals:date_start "1000"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_ECCLÉSIASTIQUE ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0439 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Ekdikoi_de_l'église_de_Sainte-Sophie_de_Constantinople> ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "13e -14e siècles"^^xsd:string ;
#     OntoSeals:date_end "1300"^^xsd:int ;
#     OntoSeals:date_start "1200"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_ECCLÉSIASTIQUE ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# ...
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004
# 		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0539 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Or ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Romain_Ier_Lécapène;Constantin_VII;Christophore> ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "921 – 924"^^xsd:string ;
#     OntoSeals:date_end "924"^^xsd:int ;
#     OntoSeals:date_start "921"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#BULLE_D'OR_DE_2_SOLIDI> ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0551 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Samuel_Alousianos ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "dernier tiers du 11e s."^^xsd:string ;
#     OntoSeals:date_end "1100"^^xsd:int ;
#     OntoSeals:date_start "1075"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire "MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2004-0583 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Alexis_I_Comnène ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "1081 – 1118"^^xsd:string ;
#     OntoSeals:date_end "1118"^^xsd:int ;
#     OntoSeals:date_start "1081"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:BULLE_IMPÉRIALE ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Don de la Fondation Migore, legs Janet Zakos, 2004		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:CdN_2008-0049 a OntoSeals:Sceau,
#         owl:NamedIndividual ;
#     OntoSeals:a_materiel OntoSeals:Plomb ;
#     OntoSeals:a_periode OntoSeals:Moyen_Age ;
#     OntoSeals:appartient_a OntoSeals:Constantin_Lascaris_Comnène ;
#     OntoSeals:avers "dans uncercle de grènetis,Viergeassise,de face, sur untrône bas, au piètement de perles , garni d’ uncoussin; pieds posés sur unsouppédion, elle tientdevant ellel’Enfant,main droitesur son épaule , la gauche le long du corps du Christquibénitde la droiteet tient unrouleaude la gauche. De part et d’ autre dunimbe, les sigles pour :"^^xsd:string ;
#     OntoSeals:bibliographie "Spink. Byzantine Seals from the collection of Georges Zacos,Part II, Auction 132. Londres, 1999 (25.5)., n° 208Zacos G., Veglery A., Byzantine lead seals, Allemagne, 1972, planches, vol I, page de titreCampagnolo-Pothitou Maria, Cheynet Jean-Claude, Sceaux de la collection George Zacos au Musée d'art et d'histoire de Genève, [Collections byzantines du MAH, Genève, 5], Milan, 5 Continents, 2016, p. 314, n° 275 "^^xsd:string ;
#     OntoSeals:date "avant 1203"^^xsd:string ;
#     OntoSeals:date_end "1203"^^xsd:int ;
#     OntoSeals:date_start "None"^^xsd:int ;
#     OntoSeals:description "Bénéficiaire de donations importantes , tant de la part de fidèles de condition modeste que de grandes familles aristocratiques , voire de l’ empereur lui-même , l’ Église avait pour charge principale de venir en aide aux indigents par des oeuvres de charité ponctuelles ( distributions de vivres , accès aux bains , rachats de prisonniers de guerre ) , ou de long terme ( entretien d’ hospices , d’ hôpitaux ou d’ orphelinats ) . La légende « parlante » de ce sceau unique fait allusion à la tâche impartie à l’ économe de la Grande Église et à son bureau , l’ Οἰκονομεῖον , à savoir seconder lepatriarchede Constantinople pour gérer au mieux la fortune de l’ institution dans l’ intérêt des ayants droit .La Viergeelle-même , représentée au droit du sceau , seportegarante du bon fonctionnement de l’ Oἰκονομεῖον de la Grande Église , en sa qualité de patronne de Constantinople et de donataire de Sainte-Sophie parJustinien Ier( ainsi figure -t -elle sur les sceaux des ekdikoi ) . Les empereursà ses côtés, outre la dévotion qu’ ils lui témoignent , tiennent les chrysobulles de donation à la Grande Église ."^^xsd:string ;
#     OntoSeals:est_de_type OntoSeals:SCEAU_BYZANTIN ;
#     OntoSeals:mentionObligatoire """
# MAH Musée d'art et d'histoire, Ville de Genève. Achat, 2008		""" ;
#     OntoSeals:revers "légende métrique , accentuée , sur six lignes , précédée d’ unecroisette:"^^xsd:string .
#
# OntoSeals:a_collection a owl:ObjectProperty ;
#     rdfs:domain OntoSeals:Sceau ;
#     rdfs:range OntoSeals:Collection .
#
# OntoSeals:a_materiel a owl:ObjectProperty ;
#     rdfs:domain OntoSeals:Sceau ;
#     rdfs:range OntoSeals:Materiel .
#
# OntoSeals:a_periode a owl:ObjectProperty ;
#     rdfs:domain OntoSeals:Sceau ;
#     rdfs:range OntoSeals:Periode .
#
# OntoSeals:appartient_a a owl:ObjectProperty ;
#     rdfs:domain OntoSeals:Sceau ;
#     rdfs:range OntoSeals:Personne .
#
# OntoSeals:avers a owl:DatatypeProperty .
#
# OntoSeals:bibliographie a owl:DatatypeProperty .
#
# OntoSeals:date a owl:DatatypeProperty .
#
# OntoSeals:date_end a owl:DatatypeProperty .
#
# OntoSeals:date_start a owl:DatatypeProperty .
#
# OntoSeals:description a owl:DatatypeProperty .
#
# OntoSeals:est_de_type a owl:ObjectProperty ;
#     rdfs:domain OntoSeals:Sceau ;
#     rdfs:range OntoSeals:Titre .
#
# OntoSeals:mentionObligatoire a owl:DatatypeProperty .
#
# OntoSeals:revers a owl:DatatypeProperty .
#
# OntoSeals:Alexis_I_Comnène a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Alexis_Stouditès a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Alliage_cuivreux a OntoSeals:Materiel,
#         owl:NamedIndividual .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Alliage_cuivreux;_petite_cavité_au_milieu_de_deux_faces> a OntoSeals:Materiel,
#         owl:NamedIndividual .
#
# OntoSeals:Athanase_Ier a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:BAGUE_SIGILLAIRE a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:BOULLÔTÈRION a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#BULLE_D'OR_DE_2_SOLIDI> a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#BULLE_D'OR_DE_5_SOLIDI> a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:Constantin_IX_Monomaque a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Constantin_Lascaris_Comnène a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Ekdikoi_de_l'église_de_Sainte-Sophie_de_Constantinople> a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Empire_byzantin a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Fer a OntoSeals:Materiel,
#         owl:NamedIndividual .
#
# OntoSeals:Grégoire a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Humbert a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Jean a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Joseph a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Liveros a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Léontios a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Maria_Makrembolitissa a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Maria_Sklèraina a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Michel_Atouémès a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Michel_Stryphnos a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Michel_VIII_Palaiologue a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Nicéphore_de_Méloé a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Periode a owl:Class .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Romain_Ier_Lécapène;Constantin_VII;Christophore> a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Samuel_Alousianos a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Sophia a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Théodora a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Théodora_Doukaina_Palaiologhina a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Tibère_Empire_byzantin_Justinien_II a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Trésor_de_la_Grande_Eglise a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Vitalès_Marztellos a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Zôsimas_Rhizaios a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Anonyme a OntoSeals:Personne,
#         owl:NamedIndividual .
#
# OntoSeals:Collection a owl:Class .
#
# OntoSeals:SCEAU_ECCLÉSIASTIQUE a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:SCEAU_PATRIARCAL a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:TESSÈRE_DE_CHARITÉ a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:Or a OntoSeals:Materiel,
#         owl:NamedIndividual .
#
# OntoSeals:BULLE_IMPÉRIALE a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:Materiel a owl:Class .
#
# OntoSeals:Titre a owl:Class .
#
# OntoSeals:SCEAU_BYZANTIN a OntoSeals:Titre,
#         owl:NamedIndividual .
#
# OntoSeals:Plomb a OntoSeals:Materiel,
#         owl:NamedIndividual .
#
# OntoSeals:Personne a owl:Class .
#
# OntoSeals:Sceau a owl:Class .
# <Graph identifier=N0454616382db4d8e8205c5898b8cf60d (<class 'rdflib.graph.Graph'>)>

# %%
###CODE BON FINAL POUR CREER LES CLASSES, SOUSCLASSES, ET LES INSTANCES DE OBJET ET PERSO
import xml.etree.ElementTree as ET
from rdflib import Graph, RDF, URIRef, Namespace, OWL, RDFS

OntoSeals = Namespace("http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#")

# Charger le fichier XML
tree = ET.parse('Sceaux_byzantins_v20_Asmae.xml')
root = tree.getroot()

# Créer un graph RDF
g = Graph()

# Dictionnaire pour suivre les noms d'individus et leurs numéros d'incrémentation
instance_dict = {}

# Fonction pour générer un nom d'instance avec un numéro d'incrémentation
def generate_instance_name(name, num):
    return f"{name}{num}"

# Parcourir les balises Seal
for sea in root.findall('.//Seal'):
    # Réinitialiser le dictionnaire à chaque nouveau sceau
    instance_dict = {}

    # Extraire la valeur de l'inventaire à partir de la balise XML <Inventaire> dans la balise <Seal>
    inventaire_element = sea.find('Inventaire')

    # Vérifier si la balise <Inventaire> existe dans cette balise <Seal>
    if inventaire_element is not None:
        inventaire = inventaire_element.text  # Récupérer le texte à l'intérieur de la balise <Inventaire>
        invent = inventaire.strip().replace(" ", "_")
        inven = URIRef(inst[invent])
        g.add((inven, RDF.type, OntoSeals['Sceau']))
    else:
        # Si la balise <Inventaire> n'est pas trouvée, vous pouvez gérer ce cas ici
        pass

    for seal in root.findall('.//Avers'):
        for objet in seal.findall('.//Objet'):
            majorType = objet.get('majorType')
            minorType = objet.get('minorType')

            # Vérifier si objet.text n'est pas None avant de le manipuler
            if objet.text is not None:
                individual_name = objet.text.strip().capitalize().replace(" ", "_")

                # Vérifier si l'individu existe déjà dans le dictionnaire
                if individual_name in instance_dict:
                    # Si l'individu existe déjà, incrémentez le numéro d'incrémentation
                    num = instance_dict[individual_name] + 1
                    new_individual_name = generate_instance_name(individual_name, num)
                    instance_dict[individual_name] = num
                else:
                    # Si l'individu n'existe pas, ajoutez-le au dictionnaire avec un numéro d'incrémentation initial de 1
                    instance_dict[individual_name] = 1
                    new_individual_name = generate_instance_name(individual_name, 1)

                # Créer une nouvelle instance avec le nom mis à jour
                individual_uri = URIRef(inst[new_individual_name])

                # Créer une sous-classe pour le majorType s'il n'existe pas
                if majorType is not None:
                    major_class_uri = URIRef(OntoSeals[majorType.capitalize().replace(' ', '_')])
                    if (major_class_uri, RDF.type, RDFS.Class) not in g:
                        g.add((major_class_uri, RDF.type, RDFS.Class))
                        g.add((major_class_uri, RDFS.subClassOf, OntoSeals['Objet']))

                # Créer une sous-sous-classe pour le minorType
                if minorType is not None:
                    minor_class_uri = URIRef(OntoSeals[minorType.capitalize().replace(' ', '_')])
                    if (minor_class_uri, RDF.type, RDFS.Class) not in g:
                        g.add((minor_class_uri, RDF.type, RDFS.Class))
                        g.add((minor_class_uri, RDFS.subClassOf, major_class_uri))

                # Ajouter l'individual en tant qu'instance de la sous-sous-classe minorType
                g.add((individual_uri, RDF.type, minor_class_uri))

        for objet1 in seal.findall('.//Personnage'):
            majorType1 = objet1.get('majorType')
            minorType1 = objet1.get('minorType')
            type1 = objet1.get('type')
            if majorType1 is not None:
                major_class_uri1 = URIRef(OntoSeals[majorType1.capitalize().replace(' ', '_')])
                if (major_class_uri1, RDF.type, RDFS.Class) not in g:
                    g.add((major_class_uri1, RDF.type, RDFS.Class))
                    g.add((major_class_uri1, RDFS.subClassOf, OntoSeals['Personnage']))

            if type1 is not None:
                individual_name1 = objet1.attrib.get('minorType')
                type1 = objet1.attrib.get('type')
                individual_name1 = individual_name1.strip().capitalize().replace(' ', '_')

                # Vérifier si l'individu existe déjà dans le dictionnaire
                if individual_name1 in instance_dict:
                    # Si l'individu existe déjà, incrémentez le numéro d'incrémentation
                    num = instance_dict[individual_name1] + 1
                    new_individual_name = generate_instance_name(individual_name1, num)
                    instance_dict[individual_name1] = num
                else:
                    # Si l'individu n'existe pas, ajoutez-le au dictionnaire avec un numéro d'incrémentation initial de 1
                    instance_dict[individual_name1] = 1
                    new_individual_name = generate_instance_name(individual_name1, 1)

                # Créer une nouvelle instance avec le nom mis à jour
                individual_uri1 = URIRef(inst[new_individual_name])

                minor_class_uri1 = URIRef(OntoSeals[type1.capitalize().replace(' ', '_')])
                if (minor_class_uri1, RDF.type, RDFS.Class) not in g:
                    g.add((minor_class_uri1, RDF.type, RDFS.Class))
                    g.add((minor_class_uri1, RDFS.subClassOf, major_class_uri1))
                g.add((individual_uri1, RDF.type, minor_class_uri1))

            else:
                individual_name2 = objet1.text
                if individual_name2 is not None:
                    individual_name2 = individual_name2.strip().capitalize().replace(" ", "_")

                    # Vérifier si l'individu existe déjà dans le dictionnaire
                    if individual_name2 in instance_dict:
                        # Si l'individu existe déjà, incrémentez le numéro d'incrémentation
                        num = instance_dict[individual_name2] + 1
                        new_individual_name = generate_instance_name(individual_name2, num)
                        instance_dict[individual_name2] = num
                    else:
                        # Si l'individu n'existe pas, ajoutez-le au dictionnaire avec un numéro d'incrémentation initial de 1
                        instance_dict[individual_name2] = 1
                        new_individual_name = generate_instance_name(individual_name2, 1)

                    # Créer une nouvelle instance avec le nom mis à jour
                    individual_uri2 = URIRef(inst[new_individual_name])
                    g.add((individual_uri2, RDF.type, major_class_uri1))

# Serialisez et affichez le graphe RDF
result = g.serialize(format="turtle")
print(result)

### A copier dans le fichier généré au préalable
# Out:
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Arme> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Arme> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cadre> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage_biblique> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Couronne_de_feuillage> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Symboles> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Symboles> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Dome> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Etendart> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_politique> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Globe> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Arme> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Habillements> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Hache> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Arme> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Arme> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lit> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_d_assise> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Maquette> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Monture> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_d_assise> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage_biblique> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Symboles> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_d_assise> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Symboles> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Table> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_d_assise> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vegetal> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Objet_de_decor> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Habillements> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> a rdfs:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Personnage_biblique> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Autel1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Table> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Bouclier> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0215> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0248> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0269> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0274> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0289> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0313> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0319> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0322> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0355> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0362> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0372> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0373> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0374> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0379> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0407> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0426> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0433a> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0439> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0449> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0482> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0502> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0508> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0526> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0534> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0537> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0538> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0539> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0551> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2004-0583> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#CdN_2008-0049> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Sceau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis10> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis11> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis12> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis13> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis14> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis15> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis16> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis17> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis6> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis7> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis8> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cercle_de_grènetis9> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chitôn_court1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chlamyde1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chlamyde2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Chlamyde3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ6> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ7> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ8> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ9> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ_emmanuel1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Coiffe_carrée1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Couronne_de_feuillage1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Couronne_de_feuillage> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Court_chitôn1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Coussin1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Coussin2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Coussin3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette_faite_de_trois_perles1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette_pattée_dans_un_clipeus1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix_gravée1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix_patriarcale1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croix> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cuirasse1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cuirasse2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cuirasse3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Deux_cercles_de_grènetis1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cerclesgrenetis> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Dôme1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Dome> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Dôme2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Dome> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Enfant6> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Feuillage1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vegetal> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Globe1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Globe> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Grand_palmier1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vegetal> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Habit_persan1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Hache1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Hache> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Himation1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Himation2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Himation3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Jesus_christ1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Jesus_christ2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Christ> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Justinien_ier1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_politique> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Labarum1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Etendart> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance_au_manche_orné_de_trois_boules1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lance> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lit1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lit> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Lôros1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Maphorion1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Maphorion2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Maphorion3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Modèle_de_l'_église_de_sainte-sophie1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Mère_de_dieu1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_au_buste_de_l’enfant1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_avec_l’enfant1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_de_l’enfant1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Croisette> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Omophorion1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Omophorion2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Panneaux_lisses1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Cadre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Patriarche1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_politique> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Phélonion1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Phélonion2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vetus> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Portail1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte_royale_ouverte1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Porte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rouleau> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Rênes_de_sa_monture1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Monture> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_georges1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_hyacinthe1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_militaire1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_nicolas1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_nicolas2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_nicolas3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_taraise1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_théodore1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Saint_théodore2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Figure_sainte> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppédion1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppédion2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppédion3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppédion4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppédion5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Souppedion> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Thôkos1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Thôkos2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône_bas1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône_bas2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône_à_haut_dossier1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trône_à_haut_dossier2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Trone> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_episkepsis1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie10> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie11> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie5> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie6> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie7> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie8> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie9> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_nikopoios1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_platytera1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Vierge_marie> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Évangiles1> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Évangiles2> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Évangiles3> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Évangiles4> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Livre> .

# %%
###CODE BON FINAL POUR CREER LES RELATIONS ENTRE SCEAUX, OBJETS ET PERSO AVEC LA NUMEROTATION
import xml.etree.ElementTree as ET
from rdflib import Graph, RDF, URIRef, Namespace, OWL, RDFS

# Charger le fichier XML
tree = ET.parse('Sceaux_byzantins_v20_Asmae.xml')
root = tree.getroot()

# Créer un graph RDF
g = Graph()

# Dictionnaire pour suivre les noms d'individus
instance_dict = {}

# Namespace RDF
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

# Namespace personnalisé pour votre ontologie
OntoSeals = Namespace("http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#")

# Définir une propriété d'objet personnalisée pour la relation 'contient'
contient = OntoSeals["contient"]


def createObjectRelation(name, domainType, rangeType):
    rel = URIRef(OntoSeals[name])
    g.add((rel, RDF.type, OWL.ObjectProperty))
    if domainType is not None:
        dom = OntoSeals[domainType]
        g.add((rel, RDFS.domain, dom))
    if rangeType is not None:
        ran = OntoSeals[rangeType]
        g.add((rel, RDFS.range, ran))
    return rel

contient_obj = createObjectRelation("contient_objet", "Sceau", "Objet")
contient_pers = createObjectRelation("contient_personnage", "Sceau", "Personnage")


# Parcourir les balises Seal
for sea in root.findall('.//Seal'):
    # Extraire la valeur de l'inventaire à partir de la balise XML <Inventaire> dans la balise <Seal>
    inventaire_element = sea.find('Inventaire')

    # Vérifier si la balise <Inventaire> existe dans cette balise <Seal>
    if inventaire_element is not None:
        inventaire = inventaire_element.text  # Récupérer le texte à l'intérieur de la balise <Inventaire>
        inventaire = inventaire.strip().replace(" ", "_")
        inven = URIRef(inst[inventaire])
        g.add((inven, RDF.type, OntoSeals['Sceau']))

        # Créer une liste pour stocker les objets associés à ce sceau
        objets_sceau = []

        # Parcourir les balises <Objet> dans la balise <Avers>
        for objet in sea.findall('.//Avers//Objet'):
            if objet.text is not None:
                individual_name = objet.text.strip().capitalize().replace(" ", "_")

                # Vérifier si l'individu existe déjà dans le dictionnaire
                counter = 1
                while True:
                    new_individual_name = f"{individual_name}{counter}"
                    if new_individual_name not in instance_dict:
                        individual_name = new_individual_name
                        break
                    counter += 1

                # Créer une nouvelle instance
                individual_uri = URIRef(inst[individual_name])

                # Ajouter l'individual à la liste des objets du sceau
                objets_sceau.append(individual_uri)

                # Ajouter l'individu au dictionnaire
                instance_dict[individual_name] = individual_uri


        # Créer une liste pour stocker les personnages associés à ce sceau
        personnages_sceau = []

        # Parcourir les balises <Personnage> dans la balise <Avers>
        for objet1 in sea.findall('.//Avers//Personnage'):
            majorType1 = objet1.get('majorType')
            minorType1 = objet1.get('minorType')
            type1 = objet1.get('type')

            if type1 is not None:
                individual_name1 = minorType1.strip().capitalize().replace(' ', '_')
                individual_uri1 = URIRef(OntoSeals[individual_name1])

                if majorType1 is not None:
                    major_class_uri1 = URIRef(OntoSeals[majorType1.capitalize().replace(' ', '_')])
                    g.add((individual_uri1, RDF.type, major_class_uri1))

                # Ajouter l'individual à la liste des personnages du sceau
                personnages_sceau.append(individual_uri1)

                # Incrémenter le numéro du nom d'individu
                if individual_name1 in instance_dict:
                    num = instance_dict[individual_name1] + 1
                    new_individual_name1 = f"{individual_name1}{num}"
                    instance_dict[individual_name1] = num
                else:
                    instance_dict[individual_name1] = 1
                    new_individual_name1 = f"{individual_name1}1"

                # Mettre à jour l'URI de l'individu avec le nom incrémenté
                individual_uri1 = URIRef(inst[new_individual_name1])

                # Mettre à jour la dernière entrée de la liste avec l'individual mis à jour
                personnages_sceau[-1] = individual_uri1

            else:
                individual_name2 = objet1.text
                if individual_name2 is not None:
                    individual_name2 = individual_name2.strip().capitalize().replace(" ", "_")

                    # Vérifier si l'individu existe déjà dans le dictionnaire
                    if individual_name2 in instance_dict:
                        # Si l'individu existe déjà, incrémentez le numéro d'incrémentation
                        num = instance_dict[individual_name2] + 1
                        new_individual_name2 = f"{individual_name2}{num}"
                        instance_dict[individual_name2] = num
                    else:
                        # Si l'individu n'existe pas, ajoutez-le au dictionnaire avec un numéro d'incrémentation initial de 1
                        instance_dict[individual_name2] = 1
                        new_individual_name2 = f"{individual_name2}1"

                    # Créer une nouvelle instance avec le nom mis à jour
                    individual_uri2 = URIRef(inst[new_individual_name2])
                    g.add((individual_uri2, RDF.type, OntoSeals['Personnage']))

                    # Ajouter l'individual à la liste des personnages du sceau
                    personnages_sceau.append(individual_uri2)

        # Ajouter la relation 'contient' entre l'inventaire et les objets du sceau
        for objet_uri in personnages_sceau:
            g.add((inven, contient_pers, objet_uri))
        for objet_uri1 in objets_sceau:
            g.add((inven, contient_obj, objet_uri1))

# Serialisez et affichez le graphe RDF
result = g.serialize(format="turtle")
print(result)
### A copier dans le fichier généré au préalable
# Out:
# @prefix ns1: <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# ns1:CdN_2004-0215 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis13,
#         ns1:Chitôn5,
#         ns1:Chlamyde2,
#         ns1:Cuirasse2,
#         ns1:Lance3,
#         ns1:Rênes_de_sa_monture1 ;
#     ns1:contient_personnage ns1:Saint_militaire1 .
#
# ns1:CdN_2004-0248 a ns1:Sceau ;
#     ns1:contient_objet <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_avec_l’enfant1> ;
#     ns1:contient_personnage ns1:Vierge_episkepsis1 .
#
# ns1:CdN_2004-0269 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis10,
#         ns1:Coussin3,
#         ns1:Souppédion2,
#         ns1:Trône2,
#         ns1:Trône_à_haut_dossier1 ;
#     ns1:contient_personnage ns1:Enfant4,
#         ns1:Vierge_platytera1 .
#
# ns1:CdN_2004-0274 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis14,
#         ns1:Maphorion2,
#         ns1:Porte2,
#         ns1:Rouleau2,
#         ns1:Souppédion5 ;
#     ns1:contient_personnage ns1:Christ8,
#         ns1:Enfant6,
#         ns1:Vierge_marie11 .
#
# ns1:CdN_2004-0289 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis12,
#         ns1:Croix4 ;
#     ns1:contient_personnage ns1:Christ_emmanuel1 .
#
# ns1:CdN_2004-0313 a ns1:Sceau ;
#     ns1:contient_objet ns1:Livre2 ;
#     ns1:contient_personnage ns1:Saint_nicolas2 .
#
# ns1:CdN_2004-0319 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis2,
#         ns1:Chitôn1,
#         ns1:Coiffe_carrée1,
#         ns1:Croix1,
#         ns1:Livre1,
#         ns1:Omophorion1,
#         ns1:Phélonion1 ;
#     ns1:contient_personnage ns1:Patriarche1,
#         ns1:Saint_taraise1 .
#
# ns1:CdN_2004-0322 a ns1:Sceau ;
#     ns1:contient_objet ns1:Croisette_faite_de_trois_perles1,
#         ns1:Globe1,
#         ns1:Labarum1,
#         ns1:Lôros1 .
#
# ns1:CdN_2004-0355 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis15,
#         ns1:Maphorion3,
#         <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_au_buste_de_l’enfant1> ;
#     ns1:contient_personnage ns1:Vierge_nikopoios1 .
#
# ns1:CdN_2004-0362 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis16,
#         ns1:Croix_gravée1 ;
#     ns1:contient_personnage ns1:Christ9 .
#
# ns1:CdN_2004-0372 a ns1:Sceau ;
#     ns1:contient_objet ns1:Bouclier1,
#         ns1:Cercle_de_grènetis5,
#         ns1:Court_chitôn1,
#         ns1:Hache1,
#         ns1:Lance1 ;
#     ns1:contient_personnage ns1:Saint_hyacinthe1,
#         ns1:Saint_théodore1 .
#
# ns1:CdN_2004-0373 a ns1:Sceau ;
#     ns1:contient_objet ns1:Chitôn2,
#         ns1:Couronne_de_feuillage1,
#         ns1:Croisette_pattée_dans_un_clipeus1,
#         ns1:Feuillage1,
#         ns1:Grand_palmier1,
#         ns1:Himation1,
#         ns1:Maphorion1,
#         ns1:Porte1 ;
#     ns1:contient_personnage ns1:Enfant3,
#         ns1:Vierge_marie4,
#         ns1:Vierge_marie5 .
#
# ns1:CdN_2004-0374 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis4,
#         ns1:Omophorion2,
#         ns1:Phélonion2,
#         ns1:Évangiles1 ;
#     ns1:contient_personnage ns1:Saint_nicolas1 .
#
# ns1:CdN_2004-0379 a ns1:Sceau ;
#     ns1:contient_objet ns1:Bouclier3,
#         ns1:Chlamyde3,
#         ns1:Cuirasse3,
#         ns1:Lance_au_manche_orné_de_trois_boules1 ;
#     ns1:contient_personnage ns1:Saint_théodore2 .
#
# ns1:CdN_2004-0407 a ns1:Sceau ;
#     ns1:contient_objet ns1:Souppédion4 ;
#     ns1:contient_personnage ns1:Christ5,
#         ns1:Jesus_christ2 .
#
# ns1:CdN_2004-0426 a ns1:Sceau ;
#     ns1:contient_objet ns1:Croix5,
#         ns1:Lit1 ;
#     ns1:contient_personnage ns1:Christ6,
#         ns1:Christ7,
#         ns1:Vierge_marie7,
#         ns1:Vierge_marie8,
#         ns1:Vierge_marie9 .
#
# ns1:CdN_2004-0433a a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis1,
#         ns1:Coussin1,
#         ns1:Rouleau1,
#         ns1:Souppédion1,
#         ns1:Trône_bas1 ;
#     ns1:contient_personnage ns1:Christ1,
#         ns1:Enfant1,
#         ns1:Vierge_marie1 .
#
# ns1:CdN_2004-0439 a ns1:Sceau ;
#     ns1:contient_objet ns1:Autel1,
#         ns1:Croix_patriarcale1,
#         ns1:Dôme1,
#         ns1:Dôme2,
#         <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Modèle_de_l'_église_de_sainte-sophie1>,
#         ns1:Panneaux_lisses1,
#         ns1:Portail1,
#         ns1:Porte_royale_ouverte1 ;
#     ns1:contient_personnage ns1:Justinien_ier1,
#         ns1:Vierge_marie2 .
#
# ns1:CdN_2004-0449 a ns1:Sceau ;
#     ns1:contient_objet ns1:Thôkos2,
#         ns1:Trône_bas2 ;
#     ns1:contient_personnage ns1:Enfant5,
#         ns1:Vierge_marie10 .
#
# ns1:CdN_2004-0482 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis7,
#         ns1:Croisette2 .
#
# ns1:CdN_2004-0502 a ns1:Sceau ;
#     ns1:contient_objet ns1:Livre3 ;
#     ns1:contient_personnage ns1:Saint_nicolas3 .
#
# ns1:CdN_2004-0508 a ns1:Sceau ;
#     ns1:contient_objet <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Médaillon_de_l’enfant1> ;
#     ns1:contient_personnage ns1:Vierge_marie6 .
#
# ns1:CdN_2004-0526 a ns1:Sceau ;
#     ns1:contient_objet ns1:Habit_persan1 .
#
# ns1:CdN_2004-0534 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis17,
#         ns1:Croisette4 .
#
# ns1:CdN_2004-0537 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis6,
#         ns1:Croisette1,
#         ns1:Évangiles2 ;
#     ns1:contient_personnage ns1:Christ2,
#         ns1:Jesus_christ1 .
#
# ns1:CdN_2004-0538 a ns1:Sceau .
#
# ns1:CdN_2004-0539 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis8,
#         ns1:Chitôn3,
#         ns1:Croisette3,
#         ns1:Croix2,
#         ns1:Himation2,
#         ns1:Évangiles3 ;
#     ns1:contient_personnage ns1:Christ3 .
#
# ns1:CdN_2004-0551 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis3,
#         ns1:Coussin2,
#         ns1:Thôkos1,
#         ns1:Trône1 ;
#     ns1:contient_personnage ns1:Enfant2,
#         ns1:Mère_de_dieu1,
#         ns1:Vierge_marie3 .
#
# ns1:CdN_2004-0583 a ns1:Sceau ;
#     ns1:contient_objet ns1:Cercle_de_grènetis11,
#         ns1:Chitôn4,
#         ns1:Croix3,
#         ns1:Himation3,
#         ns1:Souppédion3,
#         ns1:Trône_à_haut_dossier2,
#         ns1:Évangiles4 ;
#     ns1:contient_personnage ns1:Christ4 .
#
# ns1:CdN_2008-0049 a ns1:Sceau ;
#     ns1:contient_objet ns1:Bouclier2,
#         ns1:Cercle_de_grènetis9,
#         ns1:Chitôn_court1,
#         ns1:Chlamyde1,
#         ns1:Cuirasse1,
#         ns1:Deux_cercles_de_grènetis1,
#         ns1:Lance2 ;
#     ns1:contient_personnage ns1:Saint_georges1 .
#
# ns1:Christ a ns1:Personnage_biblique .
#
# ns1:Christ_emmanuel a ns1:Personnage_biblique .
#
# ns1:Enfant a ns1:Personnage_biblique .
#
# ns1:Jesus_christ a ns1:Personnage_biblique .
#
# ns1:Mère_de_dieu a ns1:Personnage_biblique .
#
# ns1:Vierge_episkepsis a ns1:Personnage_biblique .
#
# ns1:Vierge_marie a ns1:Personnage_biblique .
#
# ns1:Vierge_nikopoios a ns1:Personnage_biblique .
#
# ns1:Vierge_platytera a ns1:Personnage_biblique .
#
# ns1:contient_objet a owl:ObjectProperty ;
#     rdfs:domain ns1:Sceau ;
#     rdfs:range ns1:Objet .
#
# ns1:contient_personnage a owl:ObjectProperty ;
#     rdfs:domain ns1:Sceau ;
#     rdfs:range ns1:Personnage .
#
# ns1:Justinien_ier1 a ns1:Personnage .
#
# ns1:Patriarche1 a ns1:Personnage .
#
# ns1:Saint_georges1 a ns1:Personnage .
#
# ns1:Saint_hyacinthe1 a ns1:Personnage .
#
# ns1:Saint_militaire1 a ns1:Personnage .
#
# ns1:Saint_nicolas1 a ns1:Personnage .
#
# ns1:Saint_nicolas2 a ns1:Personnage .
#
# ns1:Saint_nicolas3 a ns1:Personnage .
#
# ns1:Saint_taraise1 a ns1:Personnage .
#
# ns1:Saint_théodore1 a ns1:Personnage .
#
# ns1:Saint_théodore2 a ns1:Personnage .

# %% [markdown]
# Ajout relations et classes et instances par Alex : <br>
#
# Relations : <br>
#
# bénit <br>
# pieds_poses_sur <br>
# est_vetu_avec <br>
#
# Classes : <br>
#
# Main - sous classe : MainDroite <br>
#
#
# encadrer la relation bénir pour relier aux sceaux où la relation existe.

# %%
import xml.etree.ElementTree as ET
from rdflib import Graph, RDF, URIRef, Namespace, OWL, RDFS

# Charger le fichier XML
tree = ET.parse('Sceaux_byzantins_v20_Asmae.xml')
root = tree.getroot()

# Créer un graph RDF
g = Graph()

# Dictionnaire pour suivre les noms d'individus
instance_dict = {}

# Namespace RDF
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

# Namespace personnalisé pour votre ontologie
OntoSeals = Namespace("http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#")

# Définir une propriété d'objet personnalisée pour la relation 'contient'
contient = OntoSeals["contient"]

# Définir une propriété d'objet personnalisée pour la relation 'bénit'
bénit = OntoSeals["bénit"]

# Définir une propriété d'objet personnalisée pour la relation 'pieds_posés_sur'
pieds_posés_sur = OntoSeals["pieds_posés_sur"]

# Définir une propriété d'objet personnalisée pour la relation 'est_vêtu_avec'
est_vêtu_avec = OntoSeals["est_vêtu_avec"]

# Créer la classe "Main"
g.add((OntoSeals["Main"], RDF.type, OWL.Class))

# Créer la sous-classe "MainDroite" avec une relation 'est_sous-classe_de'
g.add((OntoSeals["MainDroite"], RDF.type, OWL.Class))
g.add((OntoSeals["MainDroite"], RDFS.subClassOf, OntoSeals["Main"]))

# Créer l'instance "de_la_main_droite" qui est une sous-classe de "MainDroite"
g.add((OntoSeals["de_la_main_droite"], RDF.type, OntoSeals["MainDroite"]))


# Serialisez et affichez le graphe RDF
result = g.serialize(format="turtle")
print(result)
# Out:
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#de_la_main_droite> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#MainDroite> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Main> a owl:Class .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#MainDroite> a owl:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Main> .

# %%
import xml.etree.ElementTree as ET
from rdflib import Graph, RDF, URIRef, Namespace, OWL, RDFS

# Charger le fichier XML
tree = ET.parse('Sceaux_byzantins_v20_Asmae.xml')
root = tree.getroot()

# Créer un graph RDF
g = Graph()

# Dictionnaire pour suivre les noms d'individus
instance_dict = {}

# Namespace RDF
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")

# Namespace personnalisé pour votre ontologie
OntoSeals = Namespace("http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#")

# Définir une propriété d'objet personnalisée pour la relation 'contient'
contient = OntoSeals["contient"]

# Définir une propriété d'objet personnalisée pour la relation 'bénit'
bénit = OntoSeals["bénit"]

g.add((bénit, RDF.type, OWL.ObjectProperty))


# Définir une propriété d'objet personnalisée pour la relation 'pieds_posés_sur'
pieds_posés_sur = OntoSeals["pieds_posés_sur"]


g.add((pieds_posés_sur, RDF.type, OWL.ObjectProperty))


# Définir une propriété d'objet personnalisée pour la relation 'est_vêtu_avec'
est_vêtu_avec = OntoSeals["est_vêtu_avec"]

g.add((est_vêtu_avec, RDF.type, OWL.ObjectProperty))


tient = OntoSeals["tient"]
g.add((tient, RDF.type, OWL.ObjectProperty))

est = OntoSeals["est"]
g.add((est, RDF.type, OWL.ObjectProperty))


est_enfant_de = OntoSeals["est_enfant_de"]
g.add((est_enfant_de, RDF.type, OWL.ObjectProperty))


est_parent_de = OntoSeals["est_parent_de"]
g.add((est_parent_de, RDF.type, OWL.ObjectProperty))



g.add((OntoSeals["Nimbe"], RDF.type, OWL.Class))
g.add((OntoSeals["Nimbe"], RDFS.subClassOf, OntoSeals["Symboles"]))



# Créer la classe "Main"
g.add((OntoSeals["Main"], RDF.type, OWL.Class))

# Créer la sous-classe "MainDroite" avec une relation 'est_sous-classe_de'
g.add((OntoSeals["MainDroite"], RDF.type, OWL.Class))
g.add((OntoSeals["MainDroite"], RDFS.subClassOf, OntoSeals["Main"]))

# Créer l'instance "de_la_main_droite" qui est une sous-classe de "MainDroite"
g.add((OntoSeals["de_la_main_droite"], RDF.type, OntoSeals["MainDroite"]))

# Créer la propriété d'objet "contient"
g.add((contient, RDF.type, RDF.Property))

# Créer les sous-propriétés "contient_personnage" et "contient_objet"
contient_personnage = OntoSeals["contient_personnage"]
contient_objet = OntoSeals["contient_objet"]

g.add((contient_personnage, RDF.type, OWL.ObjectProperty))
g.add((contient_personnage, RDFS.subPropertyOf, contient))

g.add((contient_objet, RDF.type, OWL.ObjectProperty))
g.add((contient_objet, RDFS.subPropertyOf, contient))

# Serialisez et affichez le graphe RDF
result = g.serialize(format="turtle")
print(result)
# Out:
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Nimbe> a owl:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Symboles> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#bénit> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#contient_objet> a owl:ObjectProperty ;
#     rdfs:subPropertyOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#contient> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#contient_personnage> a owl:ObjectProperty ;
#     rdfs:subPropertyOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#contient> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#de_la_main_droite> a <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#MainDroite> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#est> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#est_enfant_de> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#est_parent_de> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#est_vêtu_avec> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#pieds_posés_sur> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#tient> a owl:ObjectProperty .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Main> a owl:Class .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#MainDroite> a owl:Class ;
#     rdfs:subClassOf <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#Main> .
#
# <http://www.semanticweb.org/alexa/ontologies/2023/2/untitled-ontology-4#contient> a rdf:Property .
