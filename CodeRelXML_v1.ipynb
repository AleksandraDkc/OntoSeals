# %%
# ! pip install -U spacy
# Out:
# ...
#      --------------------------------------- 12.1/12.1 MB 29.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.2
#     Uninstalling spacy-3.5.2:
#       Successfully uninstalled spacy-3.5.2
# ...
# WARNING: Ignoring invalid distribution - (c:\users\aleks\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aleks\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aleks\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\users\aleks\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\aleks\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fr-core-news-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.6.1 which is incompatible.
# ...

# %%
import spacy
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\aleks\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\aleks\AppData\Local\Temp\ipykernel_13976\572880994.py", line 1, in <cell line: 1>
#     import spacy
#   File "c:\Users\aleks\anaconda3\lib\site-packages\spacy\__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "c:\Users\aleks\anaconda3\lib\site-packages\spacy\errors.py", line 3, in <module>
#     from .compat import Literal
#   File "c:\Users\aleks\anaconda3\lib\site-packages\spacy\compat.py", line 39, in <module>
#     from thinc.api import Optimizer  # noqa: F401
#   File "c:\Users\aleks\anaconda3\lib\site-packages\thinc\api.py", line 2, in <module>
#     from .initializers import normal_init, uniform_init, glorot_uniform_init, zero_init
# ...

# %%
import xml.etree.ElementTree as ET
import lxml.etree as ET

# %%
def wrap_with_tags(text, tag):
    return f"<{tag}>{text}</{tag}>"

def process_text(text):
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(text)

    tagged_text = ""
    for token in doc:
        if token.ent_type_:
            tagged_text += wrap_with_tags(token.text, "Personnage") + " "
        elif token.pos_ == "VERB":
            tagged_text += wrap_with_tags(token.text, "Verbe") + " "
        elif token.pos_ == "NOUN":
            tagged_text += wrap_with_tags(token.text, "Objet") + " "
        else:
            tagged_text += token.text + " "

    return tagged_text.strip()


# Charger le fichier XML
tree = ET.parse(r'C:\Users\asmac\Desktop\Memoire2023\FichiersAlex\14-05\Sceaux byzantins v4 - Asmae.xml')
root = tree.getroot()

# Parcourir les balises "Avers" dans le XML
for objet in root.findall('.//Avers'):
    objet_avers = objet.text

    if objet_avers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_avers)

        # Créer une nouvelle balise "Avers" avec le texte traité
        nouvelle_balise_avers = ET.Element("Avers")
        nouvelle_balise_avers.text = texte_traite

        # Remplacer l'ancienne balise "Avers" par la nouvelle balise dans l'arbre XML
        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_avers)

        #la même chose pour la balise "Revers"
for objet in root.findall('.//Revers'):
    objet_avers = objet.text

    if objet_avers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_avers)

        
        nouvelle_balise_avers = ET.Element("Revers")
        nouvelle_balise_avers.text = texte_traite

        
        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_avers)

# Exporter le résultat modifié dans un nouveau fichier XML
tree.write("Sceaux_byzantins_v6_Asmae.xml", encoding='utf-8', xml_declaration=True)

# %%
import spacy
import xml.etree.ElementTree as ET
import lxml.etree as ET

def wrap_with_tags(text, tag):
    return f"<{tag}>{text}</{tag}>"

def process_text(text):
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(text)

    tagged_text = ""
    for token in doc:
        if token.ent_type_ == "PER":
            tagged_text += wrap_with_tags(token.text, "Personnage") + " "
        else:
            tagged_text += wrap_with_tags(token.text, token.pos_) + " "

    return tagged_text.strip()


# Charger le fichier XML
tree = ET.parse(r'C:\Users\asmac\Desktop\Memoire2023\FichiersAlex\14-05\Sceaux byzantins v4 - Asmae.xml')
root = tree.getroot()

# Parcourir les balises "Avers" dans le XML
for objet in root.findall('.//Avers'):
    objet_avers = objet.text

    if objet_avers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_avers)

        # Créer une nouvelle balise "Avers" avec le texte traité
        nouvelle_balise_avers = ET.Element("Avers")
        nouvelle_balise_avers.text = texte_traite

        # Remplacer l'ancienne balise "Avers" par la nouvelle balise dans l'arbre XML
        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_avers)

# La même chose pour la balise "Revers"
for objet in root.findall('.//Revers'):
    objet_revers = objet.text

    if objet_revers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_revers)

        nouvelle_balise_revers = ET.Element("Revers")
        nouvelle_balise_revers.text = texte_traite

        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_revers)

# Exporter le résultat modifié dans un nouveau fichier XML
tree.write("Sceaux_byzantins_v7_Asmae.xml", encoding='utf-8', xml_declaration=True)

# %%
import spacy
import xml.etree.ElementTree as ET
import lxml.etree as ET

def wrap_with_tags(text, tag, lemma=None):
    if lemma:
        return f"<{tag} lemma='{lemma}'>{text}</{tag}>"        
    else:
        return f"<{tag}>{text}</{tag}>"

def process_text(text):
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(text)

    tagged_text = ""
    for token in doc:
        if token.ent_type_ == "PER":
            tagged_text += wrap_with_tags(token.text, "Personnage") + " "
        elif token.pos_ == "VERB":
            tagged_text += wrap_with_tags(token.text, token.pos_, token.lemma_) + " "
        elif token.pos_ == "NOUN":
            tagged_text += wrap_with_tags(token.text, token.pos_, token.tag_) + " "
        else:
            tagged_text += wrap_with_tags(token.text, token.pos_) + " "

    return tagged_text.strip()


# Charger le fichier XML
tree = ET.parse(r'C:\Users\asmac\Desktop\Memoire2023\FichiersAlex\14-05\Sceaux byzantins v4 - Test1.xml')
root = tree.getroot()

# Parcourir les balises "Avers" dans le XML
for objet in root.findall('.//Avers'):
    objet_avers = objet.text

    if objet_avers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_avers)

        # Créer une nouvelle balise "Avers" avec le texte traité
        nouvelle_balise_avers = ET.Element("Avers")
        nouvelle_balise_avers.text = texte_traite

        # Remplacer l'ancienne balise "Avers" par la nouvelle balise dans l'arbre XML
        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_avers)

# La même chose pour la balise "Revers"
for objet in root.findall('.//Revers'):
    objet_revers = objet.text

    if objet_revers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_revers)

        nouvelle_balise_revers = ET.Element("Revers")
        nouvelle_balise_revers.text = texte_traite

        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_revers)

# Exporter le résultat modifié dans un nouveau fichier XML
tree.write("Sceaux_byzantins_v11_Asmae.xml", encoding='utf-8', xml_declaration=True)

# %%
import spacy
import xml.etree.ElementTree as ET
import lxml.etree as ET

def wrap_with_tags(text, tag, lemma=None):
    if lemma:
        return f"<{tag} lemma='{lemma}'>{text}</{tag}>"
    else:
        return f"<{tag}>{text}</{tag}>"

def process_text(text):
    nlp = spacy.load("fr_core_news_sm")
    doc = nlp(text)

    tagged_text = ""
    for token in doc:
        if token.ent_type_ == "PER":
            tagged_text += wrap_with_tags(token.text, "Personnage") + " "
        elif token.pos_ == "VERB":
            tagged_text += wrap_with_tags(token.text, token.pos_, lemma=token.lemma_) + " "
        elif token.pos_ == "NOUN":
            tagged_text += wrap_with_tags(token.text, token.pos_, token.tag_) + " "
        else:
            tagged_text += wrap_with_tags(token.text, token.pos_) + " "

    return tagged_text.strip()


# Charger le fichier XML
tree = ET.parse(r'C:\Users\aleks\Bureau\Test python postagging\Sceaux byzantins v4.xml')
root = tree.getroot()

# Parcourir les balises "Avers" dans le XML
for objet in root.findall('.//Avers'):
    objet_avers = objet.text

    if objet_avers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_avers)

        # Créer une nouvelle balise "Avers" avec le texte traité
        nouvelle_balise_avers = ET.Element("Avers")
        nouvelle_balise_avers.text = texte_traite

        # Remplacer l'ancienne balise "Avers" par la nouvelle balise dans l'arbre XML
        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_avers)

# La même chose pour la balise "Revers"
for objet in root.findall('.//Revers'):
    objet_revers = objet.text

    if objet_revers is not None:
        # Traiter le texte avec le code précédent
        texte_traite = process_text(objet_revers)

        nouvelle_balise_revers = ET.Element("Revers")
        nouvelle_balise_revers.text = texte_traite

        parent = objet.getparent()
        index = list(parent).index(objet)
        parent.remove(objet)
        parent.insert(index, nouvelle_balise_revers)

# Exporter le résultat modifié dans un nouveau fichier XML
tree.write("Sceaux_byzantins_v13_Asmae.xml", encoding='utf-8', xml_declaration=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\aleks\Bureau\Test python postagging\CodeRelXML_v1.ipynb Cellule 7 in <cell line: 30>()
#      <a href='vscode-notebook-cell:/c%3A/Users/aleks/Bureau/Test%20python%20postagging/CodeRelXML_v1.ipynb#W3sZmlsZQ%3D%3D?line=30'>31</a> objet_avers = objet.text
#      <a href='vscode-notebook-cell:/c%3A/Users/aleks/Bureau/Test%20python%20postagging/CodeRelXML_v1.ipynb#W3sZmlsZQ%3D%3D?line=32'>33</a> if objet_avers is not None:
#      <a href='vscode-notebook-cell:/c%3A/Users/aleks/Bureau/Test%20python%20postagging/CodeRelXML_v1.ipynb#W3sZmlsZQ%3D%3D?line=33'>34</a>     # Traiter le texte avec le code précédent
# ---> <a href='vscode-notebook-cell:/c%3A/Users/aleks/Bureau/Test%20python%20postagging/CodeRelXML_v1.ipynb#W3sZmlsZQ%3D%3D?line=34'>35</a>     texte_traite = process_text(objet_avers)
# ...
